# %% [markdown]
# ## This notebook implements a streaming architecture:
#
# Producer: Fetches live data from OpenSky and publishes it to a Google Cloud Pub/Sub Topic.
#
# Consumer: Pulls messages from the Pub/Sub Subscription, streams them into a new BigQuery table (realtime_flight_data), and immediately runs predictions using your existing BQML models.

# %% [markdown]
# ## 1. Setup and Authentication

# %% [markdown]
# Context: Installs necessary Google Cloud libraries and handles Colab authentication.
#
# Prompt: "Write a Python code block for Google Colab that performs the following:
#
# Installs the google-cloud-pubsub, google-cloud-bigquery, google-cloud-storage, and requests libraries via pip.
#
# Imports auth from google.colab and authenticates the user to the Google Cloud environment."

# %%
# Install required packages
# !pip install google-cloud-pubsub google-cloud-bigquery google-cloud-storage requests

from google.colab import auth
print("Authenticating to Google Cloud...")
auth.authenticate_user()
print("Authentication successful.")
# Out:
# Authenticating to Google Cloud...
# Authentication successful.

# %% [markdown]
# ## Cell 2: Configuration Variables

# %% [markdown]
# Context: Defines global variables for Project ID, Pub/Sub resources, and BigQuery resources.
#
# Prompt: "Create a configuration cell that defines Python variables for a Google Cloud project. Specifically, define:
#
# PROJECT_ID (e.g., 'mgmt-467-47888')
#
# REGION (e.g., 'us-central1')
#
# TOPIC_NAME (e.g., 'opensky-realtime-topic')
#
# SUBSCRIPTION_NAME (e.g., 'opensky-realtime-sub')
#
# BQ_DATASET (e.g., 'training_dataset')
#
# BQ_TABLE_REALTIME (e.g., 'realtime_flight_data')
#
# MODEL_NAME (e.g., 'flight_velocity_predictor')
#
# Finally, execute a shell command to set the gcloud config project to the defined PROJECT_ID."

# %%
# --- Configuration ---
PROJECT_ID = "mgmt-46700-471119"
REGION = "us-central1"

# Pub/Sub Configuration
TOPIC_NAME = "opensky-realtime-topic"
SUBSCRIPTION_NAME = "opensky-realtime-sub"

# BigQuery Configuration
BQ_DATASET = "training_dataset"
BQ_TABLE_REALTIME = "realtime_flight_data" # New table for streaming data
MODEL_NAME = "flight_velocity_predictor"   # The model we made in Unit 3.2

# Set the project for gcloud commands
# !gcloud config set project $PROJECT_ID
# Out:
# Updated property [core/project].

# %% [markdown]
# ## Cell 3: Infrastructure Setup (Idempotent)

# %% [markdown]
# Context: Uses Python clients to create the Topic, Subscription, Dataset, and Table if they don't already exist.
#
# Prompt: "Write a Python script using the Google Cloud SDK (google.cloud) to set up infrastructure idempotently. The script should:
#
# Initialize Pub/Sub and BigQuery clients.
#
# Create a Pub/Sub Topic if it doesn't exist.
#
# Create a Pub/Sub Subscription to that topic if it doesn't exist.
#
# Create a BigQuery Dataset if it doesn't exist.
#
# Create a BigQuery Table named realtime_flight_data if it doesn't exist.
#
# Use a schema for the table that includes fields for OpenSky data: icao24 (STRING), callsign (STRING), origin_country (STRING), time_position (INTEGER), longitude (FLOAT), latitude (FLOAT), geo_altitude (FLOAT), on_ground (BOOLEAN), velocity (FLOAT), heading (FLOAT), vertical_rate (FLOAT), and sensor_timestamp (TIMESTAMP). Handle AlreadyExists exceptions gracefully."

# %%
# !pip install google-cloud-pubsub
from google.cloud import pubsub_v1, bigquery
from google.api_core.exceptions import NotFound, AlreadyExists

# Initialize clients
publisher_client = pubsub_v1.PublisherClient()
subscriber_client = pubsub_v1.SubscriberClient()
bq_client = bigquery.Client()

# Construct full resource paths
topic_path = publisher_client.topic_path(PROJECT_ID, TOPIC_NAME)
subscription_path = subscriber_client.subscription_path(PROJECT_ID, SUBSCRIPTION_NAME)

# 1. Create Pub/Sub Topic if it doesn't exist
print(f"Checking Pub/Sub Topic: {TOPIC_NAME}...")
try:
    publisher_client.get_topic(request={"topic": topic_path})
    print(f"Topic {TOPIC_NAME} already exists.")
except NotFound:
    try:
        publisher_client.create_topic(request={"name": topic_path})
        print(f"Topic {TOPIC_NAME} created.")
    except AlreadyExists:
        print(f"Topic {TOPIC_NAME} already exists (concurrent creation).")

# 2. Create Pub/Sub Subscription if it doesn't exist
print(f"Checking Pub/Sub Subscription: {SUBSCRIPTION_NAME}...")
try:
    subscriber_client.get_subscription(request={"subscription": subscription_path})
    print(f"Subscription {SUBSCRIPTION_NAME} already exists.")
except NotFound:
    try:
        # The topic must exist before creating a subscription to it
        subscriber_client.create_subscription(
            request={"name": subscription_path, "topic": topic_path}
        )
        print(f"Subscription {SUBSCRIPTION_NAME} created.")
    except AlreadyExists:
        print(f"Subscription {SUBSCRIPTION_NAME} already exists (concurrent creation).")

# 3. Create BigQuery Dataset if it doesn't exist
dataset_id = f"{PROJECT_ID}.{BQ_DATASET}"
dataset = bigquery.Dataset(dataset_id)

print(f"Checking BigQuery Dataset: {BQ_DATASET}...")
try:
    bq_client.get_dataset(dataset_id)
    print(f"Dataset {BQ_DATASET} already exists.")
except NotFound:
    try:
        dataset = bq_client.create_dataset(dataset)
        print(f"Dataset {BQ_DATASET} created.")
    except AlreadyExists:
        print(f"Dataset {BQ_DATASET} already exists (concurrent creation).")

# 4. Create BigQuery Table if it doesn't exist
table_id = f"{PROJECT_ID}.{BQ_DATASET}.{BQ_TABLE_REALTIME}"

# Define the schema for the realtime_flight_data table
schema = [
    bigquery.SchemaField("icao24", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("callsign", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("origin_country", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("time_position", "INTEGER", mode="NULLABLE"),
    bigquery.SchemaField("last_contact", "INTEGER", mode="NULLABLE"),
    bigquery.SchemaField("longitude", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("latitude", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("baro_altitude", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("geo_altitude", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("on_ground", "BOOLEAN", mode="NULLABLE"),
    bigquery.SchemaField("velocity", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("heading", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("vertical_rate", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("squawk", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("spi", "BOOLEAN", mode="NULLABLE"),
    bigquery.SchemaField("position_source", "INTEGER", mode="NULLABLE"),
    bigquery.SchemaField("sensor_timestamp", "TIMESTAMP", mode="NULLABLE"), # Timestamp for when the data was processed
]

table = bigquery.Table(table_id, schema=schema)

print(f"Checking BigQuery Table: {BQ_TABLE_REALTIME}...")
try:
    bq_client.get_table(table_id)
    print(f"Table {BQ_TABLE_REALTIME} already exists.")
except NotFound:
    try:
        table = bq_client.create_table(table)
        print(f"Table {BQ_TABLE_REALTIME} created.")
    except AlreadyExists:
        print(f"Table {BQ_TABLE_REALTIME} already exists (concurrent creation).")

print("All required Google Cloud resources are ready.")
# Out:
# Requirement already satisfied: google-cloud-pubsub in /usr/local/lib/python3.12/dist-packages (2.33.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.51.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (1.76.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (2.38.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2.28.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (5.29.5)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (0.14.3)
# Requirement already satisfied: grpcio-status>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (1.71.2)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.27.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (1.37.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2.32.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (4.9.1)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio<2.0.0,>=1.51.3->google-cloud-pubsub) (4.15.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.27.0->google-cloud-pubsub) (8.7.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk>=1.27.0->google-cloud-pubsub) (0.58b0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.27.0->google-cloud-pubsub) (3.23.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (0.6.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2025.11.12)
# Checking Pub/Sub Topic: opensky-realtime-topic...
# Topic opensky-realtime-topic already exists.
# Checking Pub/Sub Subscription: opensky-realtime-sub...
# Subscription opensky-realtime-sub already exists.
# Checking BigQuery Dataset: training_dataset...
# Dataset training_dataset already exists.
# Checking BigQuery Table: realtime_flight_data...
# Table realtime_flight_data already exists.
# All required Google Cloud resources are ready.

# %% [markdown]
# ## Cell 4: OpenSky API Class Helper

# %% [markdown]
# Context: A helper class to interact with the REST API.
#
# Prompt: "Write a Python class named OpenSkyApi. The constructor should accept a username and password. Include a method named get_states that accepts bounding box coordinates (lmin, lmax, hmin, hmax) or an icao24 code. The method should make a GET request to https://opensky-network.org/api/states/all and return the list of flight states from the JSON response."

# %%
import requests
from collections import defaultdict

OPEN_SKY_USERNAME = "none"
OPEN_SKY_PASSWORD = "none"

class OpenSkyApi(object):
    def __init__(self, username, password):
        self._auth = (username, password)
        self._api_url = "https://opensky-network.org/api"
        self._last_requests = defaultdict(lambda: 0)

    def get_states(self, icao24=None, time_sec=None, lmin=None, lmax=None, hmin=None, hmax=None):
        params = {}
        if icao24:
            params['icao24'] = icao24
        if time_sec:
            params['time'] = time_sec
        if lmin is not None:
            params['lamin'] = lmin
        if lmax is not None:
            params['lamax'] = lmax
        if hmin is not None:
            params['lomin'] = hmin
        if hmax is not None:
            params['lomax'] = hmax

        try:
            response = requests.get(f"{self._api_url}/states/all",
                                    params=params,
                                    auth=self._auth)
            response.raise_for_status()
            data = response.json()
            return data.get('states', [])
        except requests.exceptions.RequestException as e:
            print(f"Error fetching OpenSky data: {e}")
            return []

# %% [markdown]
# ## 5. Data Processing and Publishing Function
#
# Context: Parses API data, cleans it, and pushes JSON messages to Pub/Sub.
#
# Prompt: "Create a function named process_and_publish that takes an OpenSky API response, a Pub/Sub publisher client, and a topic path.
#
# The function should:
#
# Iterate through the flight states.
#
# Map the raw list data to a dictionary with keys matching a BigQuery schema (icao24, callsign, longitude, latitude, velocity, geo_altitude, etc.).
#
# Add a current UTC timestamp field named sensor_timestamp.
#
# Filter out any records where velocity or geo_altitude are None.
#
# Publish the valid records as JSON strings to the Pub/Sub topic.
#
# Return the count of published messages."

# %%
import json
import datetime
from google.cloud import pubsub_v1

publisher_client = pubsub_v1.PublisherClient() # Re-initialize client if not globally available after split

def process_and_publish(api_response, publisher_client, topic_path):
    """Parses API response and publishes each flight as a Pub/Sub message, then cleans and filters."""
    if not api_response or 'states' not in api_response or api_response['states'] is None:
        print("No flight data received from OpenSky API.")
        return 0

    published_count = 0
    current_utc_timestamp = datetime.datetime.utcnow().isoformat() + "Z"

    for state_vector in api_response['states']:
        data = {
            "icao24": state_vector[0],
            "callsign": state_vector[1].strip() if state_vector[1] else None,
            "origin_country": state_vector[2].strip() if state_vector[2] else None,
            "time_position": state_vector[3],
            "last_contact": state_vector[4],
            "longitude": state_vector[5],
            "latitude": state_vector[6],
            "baro_altitude": state_vector[7],
            "geo_altitude": state_vector[13],
            "on_ground": state_vector[8],
            "velocity": state_vector[9],
            "heading": state_vector[10],
            "vertical_rate": state_vector[11],
            "squawk": state_vector[14] if len(state_vector) > 14 else None,
            "spi": state_vector[15] if len(state_vector) > 15 else None,
            "position_source": state_vector[16] if len(state_vector) > 16 else None,
            "sensor_timestamp": current_utc_timestamp,
        }

        if data['velocity'] is not None and data['geo_altitude'] is not None:
            message_json_string = json.dumps(data)
            message_bytes = message_json_string.encode("utf-8")
            future = publisher_client.publish(topic_path, message_bytes)
            published_count += 1
        else:
            print(f"Skipping record due to missing velocity or geo_altitude for icao24: {state_vector[0]}")
    return published_count

# %% [markdown]
# ## 6. Subscriber and Prediction Function
# Context: Pulls messages, inserts to BQ, and runs an ML.PREDICT query immediately.
#
# Prompt: "Write a function named pull_and_insert_and_predict that runs for a specified timeout period.
#
# Inside the function:
#
# Subscribe to the Pub/Sub subscription.
#
# When a message is received, parse the JSON data.
#
# Insert the row immediately into the BigQuery table realtime_flight_data.
#
# Upon successful insertion, run a BigQuery SQL query using ML.PREDICT with the model flight_velocity_predictor. The query should predict the velocity for the specific flight (identified by icao24 and sensor_timestamp) that was just inserted.
#
# Print the prediction results and acknowledge the Pub/Sub message."

# %%
import google.cloud.pubsub_v1 as pubsub_v1_module
import google.cloud.bigquery as bigquery_module
from concurrent.futures import TimeoutError
import pandas as pd # Import pandas for DataFrame conversion

subscriber_client = pubsub_v1_module.SubscriberClient() # Re-initialize client if not globally available after split
bq_client = bigquery_module.Client(project=PROJECT_ID) # Explicitly pass PROJECT_ID here

# Define resource paths/IDs within this cell for reliability
subscription_path = subscriber_client.subscription_path(PROJECT_ID, SUBSCRIPTION_NAME)
table_id = f"{PROJECT_ID}.{BQ_DATASET}.{BQ_TABLE_REALTIME}"

def pull_and_insert_and_predict(timeout=60):
    """Pulls messages from Pub/Sub, inserts into BigQuery, and runs BQML prediction.
    Returns a list of prediction results.
    """
    all_predictions = [] # List to store all prediction results

    def callback(message):
        print(f"Received message: {message.data.decode('utf-8')}")
        try:
            data_json = json.loads(message.data.decode('utf-8'))

            rows_to_insert = [data_json]
            errors = bq_client.insert_rows_json(table_id, rows_to_insert)

            if errors:
                print(f"Errors occurred during BigQuery insert: {errors}")
            else:
                print(f"Successfully inserted row for icao24={data_json.get('icao24')} into {table_id}")

                predict_query = f"""
                SELECT
                    *
                FROM
                    ML.PREDICT(MODEL `{PROJECT_ID}.{BQ_DATASET}.{MODEL_NAME}`,
                        (SELECT
                            geo_altitude AS altitude, # Alias geo_altitude to altitude
                            vertical_rate,
                            heading
                         FROM
                            `{PROJECT_ID}.{BQ_DATASET}.{BQ_TABLE_REALTIME}`
                         WHERE
                            icao24 = '{data_json['icao24']}'
                            AND sensor_timestamp = TIMESTAMP('{data_json['sensor_timestamp']}')
                         LIMIT 1))
                """
                predict_job = bq_client.query(predict_query)
                prediction_results = predict_job.result()

                for row in prediction_results:
                    prediction_dict = dict(row.items()) # Convert Row object to dictionary
                    all_predictions.append(prediction_dict) # Store the prediction result
                    print(f"BQML Prediction for icao24 {data_json['icao24']}: {prediction_dict}")
        except Exception as e:
            print(f"Error processing message or during BQML prediction: {e}")
        finally:
            message.ack()

    streaming_pull_future = subscriber_client.subscribe(subscription_path, callback=callback)
    print(f"Listening for messages on {subscription_path}... (Timeout: {timeout} seconds)\n")

    try:
        streaming_pull_future.result(timeout=timeout)
    except TimeoutError:
        streaming_pull_future.cancel()
        streaming_pull_future.result()
        print("Listening timed out. No messages received within the specified duration.")
    except Exception as e:
        print(f"An error occurred during streaming pull: {e}")
        streaming_pull_future.cancel()
        streaming_pull_future.result()

    return all_predictions

# %% [markdown]
# ## 7. Main Execution (Publisher Loop)
#
# Context: Fetches live data and calls the publish function.
#
# Prompt: "Write a script to execute the pipeline.
#
# Initialize the OpenSkyApi client (using placeholder credentials if necessary).
#
# Call the API to get flight states for a bounding box around Los Angeles (approx lat 34.0 to 34.5, lon -118.5 to -118.0).
#
# Initialize the Pub/Sub publisher client.
#
# Call the process_and_publish function to send the data to Pub/Sub.
#
# Print the number of messages successfully published."

# %%
print("Fetching flight data from OpenSky and publishing to Pub/Sub...")

# Ensure configuration variables are accessible
# TOPIC_ID, PROJECT_ID, OPEN_SKY_USERNAME, OPEN_SKY_PASSWORD are expected to be defined globally
#TOPIC_NAME = TOPIC_ID # Aligning with how other functions expect TOPIC_NAME

# Initialize OpenSky API client
opensky_api = OpenSkyApi(OPEN_SKY_USERNAME, OPEN_SKY_PASSWORD)

# Fetch states for a specific region (e.g., around a major airport)
# Adjust these coordinates as needed for your desired coverage area
lmin = 34.0
lmax = 34.5
hmin = -118.5
hmax = -118.0

states = opensky_api.get_states(lmin=lmin, lmax=lmax, hmin=hmin, hmax=hmax)

if states:
    # Initialize publisher client (if not already done globally)
    publisher_client = pubsub_v1.PublisherClient()

    # Topic path is already defined from configuration cell
    topic_path = publisher_client.topic_path(PROJECT_ID, TOPIC_NAME) # Using the now-defined TOPIC_NAME

    published_count = process_and_publish({'states': states}, publisher_client, topic_path)
    print(f"Successfully published {published_count} messages to Pub/Sub topic {TOPIC_NAME}.")
else:
    print("No states received from OpenSky API or an error occurred. No messages published.")
# Out:
# Fetching flight data from OpenSky and publishing to Pub/Sub...
# Skipping record due to missing velocity or geo_altitude for icao24: aa67c6
# Skipping record due to missing velocity or geo_altitude for icao24: a4c37e
# Skipping record due to missing velocity or geo_altitude for icao24: ab88e8
# Skipping record due to missing velocity or geo_altitude for icao24: a437cf
# Skipping record due to missing velocity or geo_altitude for icao24: a81c79
# Skipping record due to missing velocity or geo_altitude for icao24: a3f7f6
# Skipping record due to missing velocity or geo_altitude for icao24: a3479e
# Skipping record due to missing velocity or geo_altitude for icao24: a07a9b
# Skipping record due to missing velocity or geo_altitude for icao24: a945d5
# Skipping record due to missing velocity or geo_altitude for icao24: ab3e71
# Skipping record due to missing velocity or geo_altitude for icao24: a16022
# Skipping record due to missing velocity or geo_altitude for icao24: a1c420
# Skipping record due to missing velocity or geo_altitude for icao24: a2e491
# Skipping record due to missing velocity or geo_altitude for icao24: a24f35
# Successfully published 34 messages to Pub/Sub topic opensky-realtime-topic.
# /tmp/ipython-input-230726547.py:14: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   current_utc_timestamp = datetime.datetime.utcnow().isoformat() + "Z"

# %% [markdown]
# ## 8. Main Execution (Subscriber/Predictor)
#
# Context: Runs the subscriber to process the data sent in the previous step.
#
# Prompt: "Write a code block to run the pull_and_insert_and_predict function with a timeout of 60 seconds. Capture the returned predictions into a Pandas DataFrame. If predictions exist, display the head of the DataFrame; otherwise, print that no messages were received."

# %%
print("Starting to pull messages and generate predictions...")
# Run the pull_and_insert_and_predict function and get the results
predictions_list = pull_and_insert_and_predict(timeout=60) # You can adjust the timeout as needed

if predictions_list:
    predictions_df = pd.DataFrame(predictions_list)
    print("\nBQML Prediction Results (DataFrame Head):")
    display(predictions_df.head())
else:
    print("No predictions were generated or received within the timeout period.")
# Out:
# Starting to pull messages and generate predictions...
# Listening for messages on projects/mgmt-46700-471119/subscriptions/opensky-realtime-sub... (Timeout: 60 seconds)
#
# Received message: {"icao24": "abacb9", "callsign": "N851TA", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.0126, "latitude": 34.4105, "baro_altitude": 2834.64, "geo_altitude": 2887.98, "on_ground": false, "velocity": 77.66, "heading": 173.53, "vertical_rate": -0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# Received message: {"icao24": "acdeec", "callsign": "N9285C", "origin_country": "United States", "time_position": 1763941564, "last_contact": 1763941568, "longitude": -118.0316, "latitude": 34.1173, "baro_altitude": 335.28, "geo_altitude": 335.28, "on_ground": false, "velocity": 41.98, "heading": 143.97, "vertical_rate": -4.23, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# Received message: {"icao24": "a316d8", "callsign": "N2989U", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.4528, "latitude": 34.0162, "baro_altitude": 0, "geo_altitude": 15.24, "on_ground": false, "velocity": 0, "heading": 0, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# Received message: {"icao24": "a92872", "callsign": "N69AW", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.492, "latitude": 34.2062, "baro_altitude": 2247.9, "geo_altitude": 2301.24, "on_ground": false, "velocity": 90.64, "heading": 92.6, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# Received message: {"icao24": "aa18fc", "callsign": "N75PG", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.3947, "latitude": 34.3464, "baro_altitude": 6096, "geo_altitude": 6256.02, "on_ground": false, "velocity": 119.51, "heading": 335.86, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# Received message: {"icao24": "a47484", "callsign": "N3864M", "origin_country": "United States", "time_position": 1763941633, "last_contact": 1763941633, "longitude": -118.4897, "latitude": 34.2102, "baro_altitude": 182.88, "geo_altitude": 205.74, "on_ground": false, "velocity": 0, "heading": 0, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# Received message: {"icao24": "aaba83", "callsign": "N7901C", "origin_country": "United States", "time_position": 1763941383, "last_contact": 1763941391, "longitude": -118.4906, "latitude": 34.199, "baro_altitude": 182.88, "geo_altitude": 213.36, "on_ground": false, "velocity": 1.15, "heading": 333.43, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# Received message: {"icao24": "a5c31b", "callsign": "SWA1373", "origin_country": "United States", "time_position": 1763941490, "last_contact": 1763941490, "longitude": -118.3677, "latitude": 34.1979, "baro_altitude": 175.26, "geo_altitude": 213.36, "on_ground": false, "velocity": 71.52, "heading": 90.82, "vertical_rate": -3.58, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# Received message: {"icao24": "a9ecdb", "callsign": "N739DX", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.3675, "latitude": 34.3669, "baro_altitude": 1607.82, "geo_altitude": 1630.68, "on_ground": false, "velocity": 42.53, "heading": 32.15, "vertical_rate": 1.95, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# Received message: {"icao24": "a7c7b5", "callsign": "N600ET", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.2811, "latitude": 34.1759, "baro_altitude": 3314.7, "geo_altitude": 3368.04, "on_ground": false, "velocity": 121.49, "heading": 154.41, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# Successfully inserted row for icao24=abacb9 into mgmt-46700-471119.training_dataset.realtime_flight_dataSuccessfully inserted row for icao24=a9ecdb into mgmt-46700-471119.training_dataset.realtime_flight_data
#
# Successfully inserted row for icao24=a7c7b5 into mgmt-46700-471119.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=aa18fc into mgmt-46700-471119.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=aaba83 into mgmt-46700-471119.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=acdeec into mgmt-46700-471119.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a316d8 into mgmt-46700-471119.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a5c31b into mgmt-46700-471119.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a92872 into mgmt-46700-471119.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a47484 into mgmt-46700-471119.training_dataset.realtime_flight_data
# BQML Prediction for icao24 aaba83: {'predicted_velocity': 59.92834367335864, 'altitude': 213.36, 'vertical_rate': 0.0, 'heading': 333.43}
# Received message: {"icao24": "a18b41", "callsign": "SKW3223", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.3883, "latitude": 34.1982, "baro_altitude": 281.94, "geo_altitude": 297.18, "on_ground": false, "velocity": 64.85, "heading": 91.82, "vertical_rate": -3.58, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# Successfully inserted row for icao24=a18b41 into mgmt-46700-471119.training_dataset.realtime_flight_data
# BQML Prediction for icao24 aa18fc: {'predicted_velocity': 148.26308732962866, 'altitude': 6256.02, 'vertical_rate': 0.0, 'heading': 335.86}
# Received message: {"icao24": "a5ba10", "callsign": "N46826", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.1821, "latitude": 34.1358, "baro_altitude": 1219.2, "geo_altitude": 1264.92, "on_ground": false, "velocity": 36.32, "heading": 285.61, "vertical_rate": -1.63, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# BQML Prediction for icao24 abacb9: {'predicted_velocity': 114.0801779029388, 'altitude': 2887.98, 'vertical_rate': -0.33, 'heading': 173.53}
# Received message: {"icao24": "a2608a", "callsign": "N252SP", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.4914, "latitude": 34.2453, "baro_altitude": 396.24, "geo_altitude": 396.24, "on_ground": false, "velocity": 48.4, "heading": 182.44, "vertical_rate": -2.28, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# BQML Prediction for icao24 a9ecdb: {'predicted_velocity': 108.22847033008102, 'altitude': 1630.68, 'vertical_rate': 1.95, 'heading': 32.15}
# Received message: {"icao24": "ab8bda", "callsign": "N843JV", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.4768, "latitude": 34.0862, "baro_altitude": 480.06, "geo_altitude": 480.06, "on_ground": false, "velocity": 61.36, "heading": 159.89, "vertical_rate": -2.93, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# BQML Prediction for icao24 a92872: {'predicted_velocity': 112.92421850372746, 'altitude': 2301.24, 'vertical_rate': 0.0, 'heading': 92.6}
# Received message: {"icao24": "a7d27e", "callsign": "N603BA", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.3141, "latitude": 34.2802, "baro_altitude": 2087.88, "geo_altitude": 2148.84, "on_ground": false, "velocity": 110.68, "heading": 334.39, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# BQML Prediction for icao24 a7c7b5: {'predicted_velocity': 122.81110568433681, 'altitude': 3368.04, 'vertical_rate': 0.0, 'heading': 154.41}
# Received message: {"icao24": "a05f76", "callsign": "N123GJ", "origin_country": "United States", "time_position": 1763941642, "last_contact": 1763941642, "longitude": -118.0484, "latitude": 34.0683, "baro_altitude": 289.56, "geo_altitude": 297.18, "on_ground": false, "velocity": 39.22, "heading": 274.51, "vertical_rate": 2.6, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# BQML Prediction for icao24 a316d8: {'predicted_velocity': 88.032165494876, 'altitude': 15.24, 'vertical_rate': 0.0, 'heading': 0.0}
# Received message: {"icao24": "a60e04", "callsign": "N49CU", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.49, "latitude": 34.2189, "baro_altitude": 228.6, "geo_altitude": 251.46, "on_ground": false, "velocity": 18.58, "heading": 175.24, "vertical_rate": -1.63, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# BQML Prediction for icao24 acdeec: {'predicted_velocity': 80.39625815162704, 'altitude': 335.28, 'vertical_rate': -4.23, 'heading': 143.97}
# Received message: {"icao24": "a2ed5a", "callsign": "SKW3655", "origin_country": "United States", "time_position": 1763941609, "last_contact": 1763941609, "longitude": -118.356, "latitude": 34.1977, "baro_altitude": 167.64, "geo_altitude": 213.36, "on_ground": false, "velocity": 66.88, "heading": 90.44, "vertical_rate": -4.23, "squawk": "0563", "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# Successfully inserted row for icao24=a2608a into mgmt-46700-471119.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a5ba10 into mgmt-46700-471119.training_dataset.realtime_flight_data
# BQML Prediction for icao24 a5c31b: {'predicted_velocity': 83.38889769992826, 'altitude': 213.36, 'vertical_rate': -3.58, 'heading': 90.82}
# Received message: {"icao24": "aa5de7", "callsign": "N7670F", "origin_country": "United States", "time_position": 1763941645, "last_contact": 1763941646, "longitude": -118.4964, "latitude": 34.2401, "baro_altitude": 487.68, "geo_altitude": 495.3, "on_ground": false, "velocity": 41.98, "heading": 162.9, "vertical_rate": -0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# Successfully inserted row for icao24=a2ed5a into mgmt-46700-471119.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=ab8bda into mgmt-46700-471119.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a7d27e into mgmt-46700-471119.training_dataset.realtime_flight_data
# BQML Prediction for icao24 a47484: {'predicted_velocity': 90.82411765275681, 'altitude': 205.74, 'vertical_rate': 0.0, 'heading': 0.0}
# Received message: {"icao24": "a9d63c", "callsign": "N733AM", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.3886, "latitude": 34.2523, "baro_altitude": 541.02, "geo_altitude": 556.26, "on_ground": false, "velocity": 43.27, "heading": 342, "vertical_rate": 1.3, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# Successfully inserted row for icao24=a60e04 into mgmt-46700-471119.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a05f76 into mgmt-46700-471119.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a9d63c into mgmt-46700-471119.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=aa5de7 into mgmt-46700-471119.training_dataset.realtime_flight_data
# BQML Prediction for icao24 a18b41: {'predicted_velocity': 84.52436126186107, 'altitude': 297.18, 'vertical_rate': -3.58, 'heading': 91.82}
# Received message: {"icao24": "a1ce84", "callsign": "N2150Y", "origin_country": "United States", "time_position": 1763941618, "last_contact": 1763941643, "longitude": -118.3758, "latitude": 34.4965, "baro_altitude": 1371.6, "geo_altitude": 1386.84, "on_ground": false, "velocity": 40.01, "heading": 81.87, "vertical_rate": -2.28, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# BQML Prediction for icao24 ab8bda: {'predicted_velocity': 80.71122338580858, 'altitude': 480.06, 'vertical_rate': -2.93, 'heading': 159.89}
# Received message: {"icao24": "a5e6aa", "callsign": "N48EF", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.417, "latitude": 34.2626, "baro_altitude": 259.08, "geo_altitude": 281.94, "on_ground": false, "velocity": 27.68, "heading": 138.01, "vertical_rate": -1.95, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# BQML Prediction for icao24 a2ed5a: {'predicted_velocity': 83.58745186531877, 'altitude': 213.36, 'vertical_rate': -4.23, 'heading': 90.44}
# Received message: {"icao24": "ab4126", "callsign": "EJA824", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.489, "latitude": 34.1965, "baro_altitude": 381, "geo_altitude": 396.24, "on_ground": false, "velocity": 106.38, "heading": 175.01, "vertical_rate": 11.7, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# BQML Prediction for icao24 a5ba10: {'predicted_velocity': 80.1962543191535, 'altitude': 1264.92, 'vertical_rate': -1.63, 'heading': 285.61}
# Received message: {"icao24": "ad942b", "callsign": "N974TA", "origin_country": "United States", "time_position": 1763941452, "last_contact": 1763941452, "longitude": -118.4455, "latitude": 34.0191, "baro_altitude": 30.48, "geo_altitude": 15.24, "on_ground": false, "velocity": 4.37, "heading": 45, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# Successfully inserted row for icao24=a1ce84 into mgmt-46700-471119.training_dataset.realtime_flight_data
# BQML Prediction for icao24 a7d27e: {'predicted_velocity': 88.20530202539436, 'altitude': 2148.84, 'vertical_rate': 0.0, 'heading': 334.39}
# Received message: {"icao24": "a3cf21", "callsign": "N3444U", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.0793, "latitude": 34.1445, "baro_altitude": 1127.76, "geo_altitude": 1150.62, "on_ground": false, "velocity": 60.74, "heading": 271.94, "vertical_rate": -2.6, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# BQML Prediction for icao24 a2608a: {'predicted_velocity': 77.22250252930498, 'altitude': 396.24, 'vertical_rate': -2.28, 'heading': 182.44}
# Received message: {"icao24": "aa12df", "callsign": "N74819", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.0627, "latitude": 34.0995, "baro_altitude": 1066.8, "geo_altitude": 1104.9, "on_ground": false, "velocity": 72.62, "heading": 157.07, "vertical_rate": -0.65, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# Successfully inserted row for icao24=ab4126 into mgmt-46700-471119.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=ad942b into mgmt-46700-471119.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=aa12df into mgmt-46700-471119.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a5e6aa into mgmt-46700-471119.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a3cf21 into mgmt-46700-471119.training_dataset.realtime_flight_data
# BQML Prediction for icao24 a60e04: {'predicted_velocity': 75.60696976143848, 'altitude': 251.46, 'vertical_rate': -1.63, 'heading': 175.24}
# Received message: {"icao24": "a1f846", "callsign": "N226LA", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.4335, "latitude": 34.2315, "baro_altitude": 350.52, "geo_altitude": 373.38, "on_ground": false, "velocity": 28.61, "heading": 142.31, "vertical_rate": -0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# BQML Prediction for icao24 a9d63c: {'predicted_velocity': 63.83045525011664, 'altitude': 556.26, 'vertical_rate': 1.3, 'heading': 342.0}
# Received message: {"icao24": "a8fb01", "callsign": "N678SA", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.2701, "latitude": 34.0756, "baro_altitude": 426.72, "geo_altitude": 434.34, "on_ground": false, "velocity": 55.65, "heading": 166.09, "vertical_rate": -0.65, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# BQML Prediction for icao24 a05f76: {'predicted_velocity': 65.98322718386478, 'altitude': 297.18, 'vertical_rate': 2.6, 'heading': 274.51}
# Received message: {"icao24": "a4e414", "callsign": "N414ME", "origin_country": "United States", "time_position": 1763941581, "last_contact": 1763941605, "longitude": -118.4898, "latitude": 34.2169, "baro_altitude": 213.36, "geo_altitude": 220.98, "on_ground": false, "velocity": 15, "heading": 174.09, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# Successfully inserted row for icao24=a1f846 into mgmt-46700-471119.training_dataset.realtime_flight_data
# BQML Prediction for icao24 aa5de7: {'predicted_velocity': 80.0017997694502, 'altitude': 495.3, 'vertical_rate': -0.33, 'heading': 162.9}
# Received message: {"icao24": "a6cb82", "callsign": "N537MA", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.4874, "latitude": 34.0266, "baro_altitude": 982.98, "geo_altitude": 998.22, "on_ground": false, "velocity": 60.33, "heading": 114.16, "vertical_rate": 0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# Successfully inserted row for icao24=a4e414 into mgmt-46700-471119.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a8fb01 into mgmt-46700-471119.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a6cb82 into mgmt-46700-471119.training_dataset.realtime_flight_data
# BQML Prediction for icao24 a1ce84: {'predicted_velocity': 101.09319987465554, 'altitude': 1386.84, 'vertical_rate': -2.28, 'heading': 81.87}
# Received message: {"icao24": "a886e4", "callsign": "N649CH", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941647, "longitude": -118.2708, "latitude": 34.1963, "baro_altitude": 2545.08, "geo_altitude": 2598.42, "on_ground": false, "velocity": 82.35, "heading": 271.79, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# Successfully inserted row for icao24=a886e4 into mgmt-46700-471119.training_dataset.realtime_flight_data
# BQML Prediction for icao24 a3cf21: {'predicted_velocity': 80.03589834215354, 'altitude': 1150.62, 'vertical_rate': -2.6, 'heading': 271.94}
# Received message: {"icao24": "a3e846", "callsign": "CXK473", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.2443, "latitude": 34.1457, "baro_altitude": 1493.52, "geo_altitude": 1539.24, "on_ground": false, "velocity": 59.24, "heading": 113, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# BQML Prediction for icao24 ab4126: {'predicted_velocity': 74.40306051188871, 'altitude': 396.24, 'vertical_rate': 11.7, 'heading': 175.01}
# Received message: {"icao24": "a99565", "callsign": "N7165G", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.3096, "latitude": 34.2724, "baro_altitude": 1097.28, "geo_altitude": 1097.28, "on_ground": false, "velocity": 43.41, "heading": 121.43, "vertical_rate": 3.58, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# BQML Prediction for icao24 aa12df: {'predicted_velocity': 89.55856223599757, 'altitude': 1104.9, 'vertical_rate': -0.65, 'heading': 157.07}
# Received message: {"icao24": "aa6bed", "callsign": "SWA1536", "origin_country": "United States", "time_position": 1763941646, "last_contact": 1763941646, "longitude": -118.4354, "latitude": 34.2604, "baro_altitude": 3238.5, "geo_altitude": 3291.84, "on_ground": false, "velocity": 143.59, "heading": 16.23, "vertical_rate": 22.76, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-23T23:47:30.658830Z"}
# BQML Prediction for icao24 a5e6aa: {'predicted_velocity': 79.59625283661948, 'altitude': 281.94, 'vertical_rate': -1.95, 'heading': 138.01}
# BQML Prediction for icao24 ad942b: {'predicted_velocity': 83.84737305581201, 'altitude': 15.24, 'vertical_rate': 0.0, 'heading': 45.0}
# BQML Prediction for icao24 a4e414: {'predicted_velocity': 74.85790680946175, 'altitude': 220.98, 'vertical_rate': 0.0, 'heading': 174.09}
# Successfully inserted row for icao24=a3e846 into mgmt-46700-471119.training_dataset.realtime_flight_data
# BQML Prediction for icao24 a1f846: {'predicted_velocity': 80.1297254177471, 'altitude': 373.38, 'vertical_rate': -0.33, 'heading': 142.31}
# Successfully inserted row for icao24=a99565 into mgmt-46700-471119.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=aa6bed into mgmt-46700-471119.training_dataset.realtime_flight_data
# BQML Prediction for icao24 a8fb01: {'predicted_velocity': 78.89207224469361, 'altitude': 434.34, 'vertical_rate': -0.65, 'heading': 166.09}
# BQML Prediction for icao24 a6cb82: {'predicted_velocity': 91.73942172244719, 'altitude': 998.22, 'vertical_rate': 0.33, 'heading': 114.16}
# BQML Prediction for icao24 a886e4: {'predicted_velocity': 100.61582037766877, 'altitude': 2598.42, 'vertical_rate': 0.0, 'heading': 271.79}
# BQML Prediction for icao24 a3e846: {'predicted_velocity': 99.85930396649518, 'altitude': 1539.24, 'vertical_rate': 0.0, 'heading': 113.0}
# BQML Prediction for icao24 a99565: {'predicted_velocity': 91.69908078653104, 'altitude': 1097.28, 'vertical_rate': 3.58, 'heading': 121.43}
# BQML Prediction for icao24 aa6bed: {'predicted_velocity': 128.82935932215636, 'altitude': 3291.84, 'vertical_rate': 22.76, 'heading': 16.23}
# Listening timed out. No messages received within the specified duration.
#
# BQML Prediction Results (DataFrame Head):
#    predicted_velocity  altitude  vertical_rate  heading
# 0           59.928344    213.36           0.00   333.43
# 1          148.263087   6256.02           0.00   335.86
# 2          114.080178   2887.98          -0.33   173.53
# 3          108.228470   1630.68           1.95    32.15
# 4          112.924219   2301.24           0.00    92.60

# %% [markdown]
# ## 9. Visualization (Predicted vs Actual)
#
# Context: Scatter plot of the results.
#
# Prompt: "Using matplotlib and seaborn, write code to visualize the prediction results stored in the predictions_df DataFrame. Create a scatter plot where the x-axis is 'heading' and the y-axis is 'predicted_velocity'. Color the points based on the predicted velocity using a 'viridis' palette."

# %%
import matplotlib.pyplot as plt
import seaborn as sns

if 'predictions_df' in locals() and not predictions_df.empty:
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x='heading', y='predicted_velocity', data=predictions_df, hue='predicted_velocity', palette='viridis')
    plt.title('Predicted Velocity vs. Heading')
    plt.xlabel('Heading (degrees)')
    plt.ylabel('Predicted Velocity')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()
else:
    print("predictions_df is not available or empty. Please ensure predictions are generated first.")

# %% [markdown]
# ## 10. Flight Path Query & Visualization
#
# Context: Queries historical data for a specific plane and plots the path.
#
# Prompt: "Write a code block that:
#
# Creates an input form field for CALLSIGN_TO_TRACK (defaulting to 'DAL339').
#
# Queries the BigQuery table realtime_flight_data to retrieve the longitude, latitude, geo_altitude, and velocity for that callsign, ordered by timestamp.
#
# Stores the result in a DataFrame.
#
# Uses Seaborn to plot a line chart of Longitude vs. Latitude to visualize the flight path.
#
# Mark the start position with a green dot and the end position with a red dot."

# %%
#@title Enter the Callsign to Track
CALLSIGN_TO_TRACK = 'N226LA' #@param {type:"string"}

print(f"You chose to track flight with Callsign: {CALLSIGN_TO_TRACK}")
# Out:
# You chose to track flight with Callsign: N226LA

# %%
from google.cloud import bigquery
import pandas as pd

bq_client = bigquery.Client(project=PROJECT_ID)

print(f"Fetching flight data for callsign: {CALLSIGN_TO_TRACK}...")

flight_path_query = f"""
SELECT
    sensor_timestamp,
    longitude,
    latitude,
    geo_altitude,
    velocity,
    heading,
    vertical_rate
FROM
    `{PROJECT_ID}.{BQ_DATASET}.{BQ_TABLE_REALTIME}`
WHERE
    callsign = '{CALLSIGN_TO_TRACK}'
ORDER BY
    sensor_timestamp ASC
"""

flight_path_job = bq_client.query(flight_path_query)
flight_path_df = flight_path_job.to_dataframe()

if not flight_path_df.empty:
    print(f"Found {len(flight_path_df)} records for {CALLSIGN_TO_TRACK}.")
    display(flight_path_df.head())
else:
    print(f"No flight data found for callsign: {CALLSIGN_TO_TRACK}")
# Out:
# Fetching flight data for callsign: N226LA...
# Found 1 records for N226LA.
#                   sensor_timestamp  longitude  latitude  geo_altitude  \
# 0 2025-11-23 23:47:30.658830+00:00  -118.4335   34.2315        373.38
#
#    velocity  heading  vertical_rate
# 0     28.61   142.31          -0.33

# %%
import matplotlib.pyplot as plt
import seaborn as sns

if 'flight_path_df' in locals() and not flight_path_df.empty:
    plt.figure(figsize=(12, 8))
    sns.lineplot(x='longitude', y='latitude', data=flight_path_df, marker='o', sort=False)
    plt.title(f'Flight Path for Callsign: {CALLSIGN_TO_TRACK}')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.grid(True, linestyle='--', alpha=0.7)

    # Optionally, add start and end points
    if len(flight_path_df) > 0:
        plt.plot(flight_path_df['longitude'].iloc[0], flight_path_df['latitude'].iloc[0], 'go', markersize=10, label='Start') # Green circle for start
        plt.plot(flight_path_df['longitude'].iloc[-1], flight_path_df['latitude'].iloc[-1], 'ro', markersize=10, label='End') # Red circle for end

    plt.legend()
    plt.show()
else:
    print("No flight path data available to plot.")

# %% [markdown]
# ## 11. Classification Model Prediction
#
# Context: Using a different model to classify if a plane is on the ground.
#
# Prompt: "Write a script to perform classification using BigQuery ML.
#
# Define a model name flight_on_ground_classifier.
#
# Construct a SQL query that uses ML.PREDICT with this model.
#
# The input data for the prediction should be the most recent 100 records from the realtime_flight_data table (selecting icao24, geo_altitude, and velocity).
#
# Execute the query and display the classification results in a DataFrame."

# %%
# Define the classification model name
CLASSIFICATION_MODEL_NAME = "flight_on_ground_classifier"

print(f"Classification Model: {CLASSIFICATION_MODEL_NAME}")
# Out:
# Classification Model: flight_on_ground_classifier

# %%
from google.cloud import bigquery
import pandas as pd

bq_client = bigquery.Client(project=PROJECT_ID)

print(f"Running classification predictions using model: {CLASSIFICATION_MODEL_NAME}...")

# Construct the prediction query for the classification model
# We will use the latest data inserted into realtime_flight_data as input
classification_predict_query = f"""
SELECT
    * EXCEPT(predicted_on_ground_probs)
FROM
    ML.PREDICT(MODEL `{PROJECT_ID}.{BQ_DATASET}.{CLASSIFICATION_MODEL_NAME}`,
        (SELECT
            icao24,
            geo_altitude AS altitude, # Alias geo_altitude to altitude as required by model
            velocity
         FROM
            `{PROJECT_ID}.{BQ_DATASET}.{BQ_TABLE_REALTIME}`
         LIMIT 100 # Limit to avoid processing too much data for demonstration
         ))
"""

classification_predict_job = bq_client.query(classification_predict_query)
classification_predictions = classification_predict_job.result()

# Convert results to a Pandas DataFrame for easy viewing
classification_predictions_df = classification_predictions.to_dataframe()

if not classification_predictions_df.empty:
    print("\nBQML Classification Prediction Results (DataFrame Head):")
    display(classification_predictions_df.head())
else:
    print("No classification predictions were generated.")
# Out:
# Running classification predictions using model: flight_on_ground_classifier...
#
# BQML Classification Prediction Results (DataFrame Head):
#    predicted_on_ground  icao24  altitude  velocity
# 0                    0  aacfed    586.74     43.24
# 1                    0  a24727   1866.90    112.05
# 2                    0  abacb9   2887.98     77.66
# 3                    0  acdeec    335.28     41.98
# 4                    1  a60e04    251.46     18.58
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['predicted_on_ground'].plot(kind='hist', bins=20, title='predicted_on_ground')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['altitude'].plot(kind='hist', bins=20, title='altitude')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['velocity'].plot(kind='hist', bins=20, title='velocity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('icao24').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='predicted_on_ground', y='altitude', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='altitude', y='velocity', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6['predicted_on_ground'].plot(kind='line', figsize=(8, 4), title='predicted_on_ground')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['altitude'].plot(kind='line', figsize=(8, 4), title='altitude')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8['velocity'].plot(kind='line', figsize=(8, 4), title='velocity')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_9['icao24'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_9, x='predicted_on_ground', y='icao24', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_10['icao24'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_10, x='altitude', y='icao24', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_11['icao24'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_11, x='velocity', y='icao24', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
